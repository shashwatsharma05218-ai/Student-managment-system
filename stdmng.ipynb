# %% [markdown]
# <a href="https://colab.research.google.com/github/shashwatsharma05218-ai/Student-managment-system/blob/main/stdmng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Management System

# %%
import sqlite3

# %%
conn = sqlite3.connect("student.db")

cursor = conn.cursor()

print("Database Connected Successfully")
# Out:
# Database Connected Successfully

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS students(

id INTEGER PRIMARY KEY AUTOINCREMENT,

name TEXT,

age INTEGER,

gender TEXT,

course TEXT,

semester INTEGER,

email TEXT,

phone TEXT,

attendance REAL,

cgpa REAL

)
""")

conn.commit()

print("Table Created Successfully")
# Out:
# Table Created Successfully

# %%
def add_student():

    name = input("Enter Name : ")

    age = int(input("Enter Age : "))

    gender = input("Gender : ")

    course = input("Course : ")

    semester = int(input("Semester : "))

    email = input("Email : ")

    phone = input("Phone : ")

    attendance = float(input("Attendance : "))

    cgpa = float(input("CGPA : "))

    cursor.execute("""
    INSERT INTO students
    (name,age,gender,course,semester,email,phone,attendance,cgpa)

    VALUES (?,?,?,?,?,?,?,?,?)
    """,

    (name,age,gender,course,semester,email,phone,attendance,cgpa))

    conn.commit()

    print("Student Added Successfully")

# %%
add_student()
# Out:
# Enter Name : gfd
# Enter Age : 22
# Gender : female
# Course : btech
# Semester : 6
# Email : gfd@gmail.com
# Phone : 1111111112
# Attendance : 77
# CGPA : 8
# Student Added Successfully

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def view_students():

    cursor.execute("SELECT * FROM students")

    rows = cursor.fetchall()

    for row in rows:

        print(row)

# %%
view_students()
# Out:
# (1, 'abc', 20, 'male', 'btech', 6, 'abg@gmil.com', '111111111', 67.0, 6.0)

# %%
def search_student():

    name = input("Enter Student Name : ")

    cursor.execute(

        "SELECT * FROM students WHERE name=?",

        (name,)
    )

    result = cursor.fetchall()

    if result:

        for student in result:

            print(student)

    else:

        print("Student Not Found")

# %%
search_student()
# Out:
# Enter Student Name : gfd
# (2, 'gfd', 22, 'female', 'btech', 6, 'gfd@gmail.com', '1111111112', 77.0, 8.0)

# %%
def delete_student():

    sid = int(input("Enter Student ID : "))

    cursor.execute(

        "DELETE FROM students WHERE id=?",

        (sid,)
    )

    conn.commit()

    print("Student Deleted Successfully")

# %%
delete_student()
# Out:
# Enter Student ID : 1
# Student Deleted Successfully

# %%
def update_student():

    sid = int(input("Enter Student ID : "))

    new_name = input("New Name : ")

    new_cgpa = float(input("New CGPA : "))

    cursor.execute("""

    UPDATE students

    SET name=?,

    cgpa=?

    WHERE id=?

    """,

    (new_name,new_cgpa,sid))

    conn.commit()

    print("Updated Successfully")

# %%
update_student()
# Out:
# Enter Student ID : 2
# New Name : fgd
# New CGPA : 9
# Updated Successfully

# %%
while True:

    print("\n===== STUDENT MANAGEMENT SYSTEM =====")

    print("1. Add Student")

    print("2. View Students")

    print("3. Search Student")

    print("4. Update Student")

    print("5. Delete Student")

    print("6. Exit")

    choice = input("Enter Choice : ")

    if choice=="1":

        add_student()

    elif choice=="2":

        view_students()

    elif choice=="3":

        search_student()

    elif choice=="4":

        update_student()

    elif choice=="5":

        delete_student()

    elif choice=="6":

        print("Thank You")

        break

    else:

        print("Invalid Choice")
# Out:
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Choice : 1
# Enter Name : xyz
# Enter Age : 20
# Gender : male
# Course : btech
# Semester : 8
# Email : xyz@gmail.com
# Phone : 99999999
# Attendance : 78
# CGPA : 8
# Student Added Successfully
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Choice : 6
# Thank You

# %%
conn.close()

print("Database Closed")
# Out:
# Database Closed
